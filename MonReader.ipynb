# %% [markdown]
# <a href="https://colab.research.google.com/github/shamjam/EvbzcY2OC75BRZuM/blob/main/MonReader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Project 4: MonReader
# MonReader is a mobile application that digitizes books for a user by capturing pages, as they are being flipped by the user.
#
# Our goal in this project is to build a model that predicts if an image of a page shows if the page is being flipped (or not). We will also aim to predict if a given sequence of images contain an action of flipping.

# %% [markdown]
# ### Project Setup

# %%
# Import the necessary packages
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dense
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical

import cv2
import glob
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Set train and test set paths
TRAIN_PATH = "/content/gdrive/MyDrive/Datasets/MonReader/images/training"
TEST_PATH = "/content/gdrive/MyDrive/Datasets/MonReader/images/testing"

# %% [markdown]
# ### Data Exploration
#
#
# *   Data is labelled as 'flipping' or 'not flipping'
# *   The extracted frames have been stored with the naming structure: *VideoID_FrameNumber*

# %%
train_image_paths_flip = glob.glob(TRAIN_PATH + "/flip/*")
train_image_paths_notflip = glob.glob(TRAIN_PATH + "/notflip/*")
test_image_paths_flip = glob.glob(TEST_PATH + "/flip/*")
test_image_paths_notflip = glob.glob(TEST_PATH + "/notflip/*")

# %%
print(f"There are {len(train_image_paths_flip)} 'flip' images and {len(train_image_paths_notflip)} 'notflip' images in the training set")
print(f"There are {len(test_image_paths_flip)} 'flip' images and {len(test_image_paths_notflip)} 'notflip' images in the testing set")
# Out:
# There are 1162 'flip' images and 1230 'notflip' images in the training set
# There are 290 'flip' images and 307 'notflip' images in the testing set

# %% [markdown]
# ### Design the Model
# For an initial benchmark, we will use the LeNet network.

# %%
class LeNet:
  @staticmethod
  def build(width, height, depth, classes):
    # initialize the model
    model = Sequential()
    input_shape = (height, width, depth)

    # first set of CONV => RELU => POOL layers
    model.add(Conv2D(20, (5, 5), padding="same", input_shape=input_shape))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    # second set of CONV => RELU => POOL layers
    model.add(Conv2D(50, (5, 5), padding="same"))
    model.add(Activation("relu"))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    # first (and only) set of FC => RELU layers
    model.add(Flatten())
    model.add(Dense(500))
    model.add(Activation("relu"))

    # softmax classifier
    model.add(Dense(classes))
    model.add(Activation("softmax"))

    # return the constructed network architecture
    return model

# %% [markdown]
# ### Train the Model

# %%
# Initialize the list of data and labels
data = []
labels = []

# Loop over all the images in the training set
for image_path in sorted(train_image_paths_notflip):
  # Load the image
  image = cv2.imread(image_path)

  # Convert it to grayscale, and re-size it
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.resize(image, (28, 28))

  # Store the image in the data list
  image = img_to_array(image)
  data.append(image)

  # Store the label of the image in the data list
  labels.append("notflip")

# Do the same for the 'notflip' set
for image_path in sorted(train_image_paths_flip):
  # Load the image
  image = cv2.imread(image_path)

  # Convert it to grayscale, and re-size it
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.resize(image, (28, 28))

  # Store the image in the data list
  image = img_to_array(image)
  data.append(image)

  # Store the label of the image in the data list
  labels.append("flip")

# %%
# Scale the raw pixel intensities to the range [0, 1]
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# Convert the labels from integers to vectors
le = LabelEncoder().fit(labels)
labels = to_categorical(le.transform(labels), 2)

# %%
# Save the training data
np.save('/content/gdrive/MyDrive/Datasets/MonReader/train_data.npy', data)
np.save('/content/gdrive/MyDrive/Datasets/MonReader/train_labels.npy', labels)

# %%
# Pre-process test set
# Initialize the list of data and labels
test_data = []
test_labels = []

# Loop over all the images in the training set
for image_path in sorted(test_image_paths_notflip):
  # Load the image
  image = cv2.imread(image_path)

  # Convert it to grayscale, and re-size it
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.resize(image, (28, 28))

  # Store the image in the data list
  image = img_to_array(image)
  test_data.append(image)

  # Store the label of the image in the data list
  test_labels.append("notflip")

# Do the same for the 'notflip' set
for image_path in sorted(test_image_paths_flip):
  # Load the image
  image = cv2.imread(image_path)

  # Convert it to grayscale, and re-size it
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.resize(image, (28, 28))

  # Store the image in the data list
  image = img_to_array(image)
  test_data.append(image)

  # Store the label of the image in the data list
  test_labels.append("flip")

# %%
# Scale the raw pixel intensities to the range [0, 1]
testX = np.array(test_data, dtype="float") / 255.0
labels = np.array(test_labels)

# Convert the labels from integers to vectors
le = LabelEncoder().fit(labels)
testY = to_categorical(le.transform(labels), 2)

# TODO: Try label 0 and 1 for trainY and testY elements

# %%
# Save the testing data
np.save('/content/gdrive/MyDrive/Datasets/MonReader/test_data.npy', testX)
np.save('/content/gdrive/MyDrive/Datasets/MonReader/test_labels.npy', testY)

# %%
# Load the training data
data = np.load('/content/gdrive/MyDrive/Datasets/MonReader/train_data.npy')
labels = np.load('/content/gdrive/MyDrive/Datasets/MonReader/train_labels.npy')

# %%
# Load the testing data
testX = np.load('/content/gdrive/MyDrive/Datasets/MonReader/test_data.npy')
testY = np.load('/content/gdrive/MyDrive/Datasets/MonReader/test_labels.npy')

# %%
(trainX, validX, trainY, validY) = train_test_split(data, labels, test_size=0.20, stratify=labels, shuffle=True, random_state=42)

# %%
# Initialize the model
model = LeNet.build(width=28, height=28, depth=1, classes=2)
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the network
H = model.fit(trainX, trainY, validation_data=(validX, validY), batch_size=64, epochs=15, verbose=1)
# Out:
# Epoch 1/15
# 30/30 [==============================] - 5s 136ms/step - loss: 0.6864 - accuracy: 0.5525 - val_loss: 0.6687 - val_accuracy: 0.6033
# Epoch 2/15
# 30/30 [==============================] - 4s 131ms/step - loss: 0.6213 - accuracy: 0.6393 - val_loss: 0.5529 - val_accuracy: 0.7307
# Epoch 3/15
# 30/30 [==============================] - 7s 246ms/step - loss: 0.4845 - accuracy: 0.7799 - val_loss: 0.4171 - val_accuracy: 0.8121
# Epoch 4/15
# 30/30 [==============================] - 4s 138ms/step - loss: 0.3332 - accuracy: 0.8772 - val_loss: 0.2820 - val_accuracy: 0.8789
# Epoch 5/15
# 30/30 [==============================] - 4s 131ms/step - loss: 0.2245 - accuracy: 0.9143 - val_loss: 0.2367 - val_accuracy: 0.9207
# Epoch 6/15
# 30/30 [==============================] - 4s 131ms/step - loss: 0.1498 - accuracy: 0.9571 - val_loss: 0.1276 - val_accuracy: 0.9645
# Epoch 7/15
# 30/30 [==============================] - 4s 133ms/step - loss: 0.1229 - accuracy: 0.9582 - val_loss: 0.2261 - val_accuracy: 0.8998
# Epoch 8/15
# 30/30 [==============================] - 4s 131ms/step - loss: 0.1062 - accuracy: 0.9629 - val_loss: 0.0961 - val_accuracy: 0.9603
# Epoch 9/15
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0617 - accuracy: 0.9875 - val_loss: 0.0714 - val_accuracy: 0.9875
# Epoch 10/15
# 30/30 [==============================] - 4s 132ms/step - loss: 0.0668 - accuracy: 0.9827 - val_loss: 0.1028 - val_accuracy: 0.9749
# Epoch 11/15
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0601 - accuracy: 0.9859 - val_loss: 0.0542 - val_accuracy: 0.9812
# Epoch 12/15
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0326 - accuracy: 0.9937 - val_loss: 0.0522 - val_accuracy: 0.9812
# Epoch 13/15
# 30/30 [==============================] - 4s 131ms/step - loss: 0.0235 - accuracy: 0.9974 - val_loss: 0.0508 - val_accuracy: 0.9729
# Epoch 14/15
# 30/30 [==============================] - 4s 129ms/step - loss: 0.0166 - accuracy: 0.9969 - val_loss: 0.0357 - val_accuracy: 0.9833
# Epoch 15/15
# 30/30 [==============================] - 4s 130ms/step - loss: 0.0125 - accuracy: 0.9984 - val_loss: 0.0316 - val_accuracy: 0.9896

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(validX, batch_size=64)
print(classification_report(validY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=["notflip", "flip"]))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#      notflip       1.00      0.98      0.99       233
#         flip       0.98      1.00      0.99       246
#
#     accuracy                           0.99       479
#    macro avg       0.99      0.99      0.99       479
# weighted avg       0.99      0.99      0.99       479

# %%
# Plot the training + testing loss and accuracy
epochs=15
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, epochs), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, epochs), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, epochs), H.history["accuracy"], label="acc")
plt.plot(np.arange(0, epochs), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %%
# save the model to disk
#print("[INFO] serializing network...")
#model.save("/content/gdrive/MyDrive/Datasets/MonReader")

# %%
#print(predictions.argmax(axis=1))

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=["notflip", "flip"]))

# save the model to disk
#print("[INFO] serializing network...")
#model.save(args["model"])
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#      notflip       1.00      0.97      0.98       290
#         flip       0.97      1.00      0.99       307
#
#     accuracy                           0.98       597
#    macro avg       0.99      0.98      0.98       597
# weighted avg       0.99      0.98      0.98       597

# %%
import random

plt.figure(figsize=(10,30))
for i in range(27):
    k = random.randint(1, len(testX)-1)
    plt.subplot(9,3,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(testX[k][:,:,0], cmap=plt.cm.binary)
    plt.xlabel(f"GT: {testY[k].argmax()}, Pr: {predictions[k].argmax()}")
plt.show()

# %%
def predict_image(path=None):
  # Load the image
  image = cv2.imread(path)

  # Show the image
  plt.imshow(image)

  # Convert it to grayscale, and re-size it
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.resize(image, (28, 28))

  # Store the image in the data list
  image = img_to_array(image)

  image = np.array([image], dtype="float") / 255.0

  prediction = model.predict(image)

  return le.classes_[prediction.argmax()]

# %%
trainY.shape
# Out:
# (1913, 2)

# %%
trainY[0]
# Out:
# array([0., 1.], dtype=float32)

# %%
# Make prediction on specific image
predict_image(test_image_paths_notflip[1])
# Out:
# 'notflip'

# %%
predict_image(test_image_paths_flip[0])
# Out:
# 'flip'

# %% [markdown]
# ## Predict if a given sequence of images contains an action of flipping

# %% [markdown]
# ### Method 1: Using the image classification model
# We can use the image classification model we have just created to classify each frame of a given video. If

# %%
# Sort into sets/combine frames
test_image_paths_flip_sets = {}
for path in sorted(test_image_paths_flip):
  label = path.split(os.path.sep)[-2].split("_")[0]
  video_number = path.split(os.path.sep)[-1].split("_")[0]
  if video_number not in test_image_paths_flip_sets.keys():
    test_image_paths_flip_sets[video_number] = []
  test_image_paths_flip_sets[video_number].append(path)

test_image_paths_notflip_sets = {}
for path in sorted(test_image_paths_notflip):
  label = path.split(os.path.sep)[-2].split("_")[0]
  video_number = path.split(os.path.sep)[-1].split("_")[0]
  if video_number not in test_image_paths_notflip_sets.keys():
    test_image_paths_notflip_sets[video_number] = []
  test_image_paths_notflip_sets[video_number].append(path)

# %%
test_image_paths_flip_sets
# Out:
# {'0001': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0001_000000020.jpg'],
#  '0002': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0002_000000012.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0002_000000013.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0002_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0002_000000017.jpg'],
#  '0003': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0003_000000005.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0003_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0003_000000022.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0003_000000025.jpg'],
#  '0004': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0004_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0004_000000013.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0004_000000014.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0004_000000027.jpg'],
#  '0005': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0005_000000003.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0005_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0005_000000018.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0005_000000023.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0005_000000028.jpg'],
#  '0006': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0006_000000001.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0006_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0006_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0006_000000012.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0006_000000021.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0006_000000022.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0006_000000024.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0006_000000025.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0006_000000030.jpg'],
#  '0007': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0007_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0007_000000018.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0007_000000024.jpg'],
#  '0008': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0008_000000005.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0008_000000007.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0008_000000023.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0008_000000026.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0008_000000029.jpg'],
#  '0009': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0009_000000007.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0009_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0009_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0009_000000020.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0009_000000023.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0009_000000025.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0009_000000026.jpg'],
#  '0010': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0010_000000004.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0010_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0010_000000009.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0010_000000012.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0010_000000013.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0010_000000021.jpg'],
#  '0011': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0011_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0011_000000014.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0011_000000023.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0011_000000026.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0011_000000027.jpg'],
#  '0012': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0012_000000007.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0012_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0012_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0012_000000022.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0012_000000025.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0012_000000029.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0012_000000030.jpg'],
#  '0013': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0013_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0013_000000011.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0013_000000013.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0013_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0013_000000022.jpg'],
#  '0014': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0014_000000003.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0014_000000004.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0014_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0014_000000009.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0014_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0014_000000012.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0014_000000013.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0014_000000014.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0014_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0014_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0014_000000020.jpg'],
#  '0015': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0015_000000011.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0015_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0015_000000021.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0015_000000023.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0015_000000029.jpg'],
#  '0016': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0016_000000004.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0016_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0016_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0016_000000013.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0016_000000026.jpg'],
#  '0017': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0017_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0017_000000017.jpg'],
#  '0018': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0018_000000003.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0018_000000004.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0018_000000012.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0018_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0018_000000020.jpg'],
#  '0019': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0019_000000014.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0019_000000025.jpg'],
#  '0020': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0020_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0020_000000012.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0020_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0020_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0020_000000020.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0020_000000023.jpg'],
#  '0021': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0021_000000011.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0021_000000014.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0021_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0021_000000027.jpg'],
#  '0022': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0022_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0022_000000020.jpg'],
#  '0024': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0024_000000017.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0024_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0024_000000021.jpg'],
#  '0026': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0026_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0026_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0026_000000018.jpg'],
#  '0027': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0027_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0027_000000018.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0027_000000019.jpg'],
#  '0028': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0028_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0028_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0028_000000024.jpg'],
#  '0029': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0029_000000021.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0029_000000024.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0029_000000025.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0029_000000027.jpg'],
#  '0030': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0030_000000003.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0030_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0030_000000009.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0030_000000012.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0030_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0030_000000027.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0030_000000031.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0030_000000038.jpg'],
#  '0031': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0031_000000018.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0031_000000020.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0031_000000028.jpg'],
#  '0032': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0032_000000010.jpg'],
#  '0033': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0033_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0033_000000021.jpg'],
#  '0034': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0034_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0034_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0034_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0034_000000020.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0034_000000022.jpg'],
#  '0035': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0035_000000007.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0035_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0035_000000016.jpg'],
#  '0036': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0036_000000007.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0036_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0036_000000009.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0036_000000011.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0036_000000014.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0036_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0036_000000024.jpg'],
#  '0037': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0037_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0037_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0037_000000011.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0037_000000013.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0037_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0037_000000017.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0037_000000020.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0037_000000024.jpg'],
#  '0038': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000007.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000013.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000020.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000026.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000032.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000043.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000044.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000047.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0038_000000048.jpg'],
#  '0039': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0039_000000009.jpg'],
#  '0040': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0040_000000007.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0040_000000024.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0040_000000025.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0040_000000028.jpg'],
#  '0041': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0041_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0041_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0041_000000018.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0041_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0041_000000021.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0041_000000022.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0041_000000027.jpg'],
#  '0042': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0042_000000002.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0042_000000004.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0042_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0042_000000011.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0042_000000012.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0042_000000027.jpg'],
#  '0043': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0043_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0043_000000023.jpg'],
#  '0044': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0044_000000003.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0044_000000007.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0044_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0044_000000024.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0044_000000025.jpg'],
#  '0045': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0045_000000027.jpg'],
#  '0046': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0046_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0046_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0046_000000012.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0046_000000013.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0046_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0046_000000018.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0046_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0046_000000023.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0046_000000025.jpg'],
#  '0047': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0047_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0047_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0047_000000021.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0047_000000026.jpg'],
#  '0048': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0048_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0048_000000011.jpg'],
#  '0049': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0049_000000017.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0049_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0049_000000023.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0049_000000025.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0049_000000027.jpg'],
#  '0050': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0050_000000023.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0050_000000024.jpg'],
#  '0051': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0051_000000021.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0051_000000022.jpg'],
#  '0052': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0052_000000017.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0052_000000018.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0052_000000021.jpg'],
#  '0053': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0053_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0053_000000012.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0053_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0053_000000018.jpg'],
#  '0054': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0054_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0054_000000011.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0054_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0054_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0054_000000024.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0054_000000027.jpg'],
#  '0055': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0055_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0055_000000024.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0055_000000027.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0055_000000028.jpg'],
#  '0056': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0056_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0056_000000030.jpg'],
#  '0057': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0057_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0057_000000030.jpg'],
#  '0058': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0058_000000003.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0058_000000004.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0058_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0058_000000019.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0058_000000021.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0058_000000027.jpg'],
#  '0059': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0059_000000015.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0059_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0059_000000017.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0059_000000020.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0059_000000028.jpg'],
#  '0060': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000004.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000008.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000013.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000032.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000037.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000038.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000043.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000044.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000052.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000053.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0060_000000055.jpg'],
#  '0061': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0061_000000010.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0061_000000011.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0061_000000018.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0061_000000026.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0061_000000027.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0061_000000029.jpg'],
#  '0062': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0062_000000003.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0062_000000006.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0062_000000009.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0062_000000011.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0062_000000012.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0062_000000013.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0062_000000018.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0062_000000020.jpg'],
#  '0063': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0063_000000011.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0063_000000014.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0063_000000023.jpg'],
#  '0064': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0064_000000027.jpg'],
#  '0065': ['/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0065_000000001.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0065_000000005.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0065_000000016.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0065_000000023.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0065_000000025.jpg',
#   '/content/gdrive/MyDrive/Datasets/MonReader/images/testing/flip/0065_000000026.jpg']}

# %%
# Make predictions for each set
predictions = []
labels = []
for sequence in test_image_paths_flip_sets:
  sequence_predictions = []
  labels.append("flip")
  for image in test_image_paths_flip_sets[sequence]:
    sequence_predictions.append(predict_image(image))
  predictions.append("flip") if "flip" in sequence_predictions else predictions.append("notflip")

for sequence in test_image_paths_notflip_sets:
  sequence_predictions = []
  labels.append("notflip")
  for image in test_image_paths_notflip_sets[sequence]:
    sequence_predictions.append(predict_image(image))
  predictions.append("flip") if "flip" in sequence_predictions else predictions.append("notflip")

# %%
# Convert predictions and labels to vectors
le = LabelEncoder().fit(labels)
labels = to_categorical(le.transform(labels), 2)

le = LabelEncoder().fit(predictions)
predictions = to_categorical(le.transform(predictions), 2)

# %%
# Show classification report
print(classification_report(labels.argmax(axis=1),
	predictions.argmax(axis=1), target_names=["notflip", "flip"]))
# Out:
#               precision    recall  f1-score   support
#
#      notflip       0.98      1.00      0.99        63
#         flip       1.00      0.98      0.99        52
#
#     accuracy                           0.99       115
#    macro avg       0.99      0.99      0.99       115
# weighted avg       0.99      0.99      0.99       115

# %%
# TODO: Try on own images/video

# %% [markdown]
# ## Summary
# (TODO)
